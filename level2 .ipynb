# %%
#outfit Generator using open AI
import openai

# Set your GPT-3 API key here
openai.api_key = "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"

def generate_outfit_suggestion(user_input, dataset_input):
    prompt = f"User: {user_input}\nDataset: {dataset_input}\nGenAI:"
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100
    )

    return response.choices[0].text.strip()

def main():
    print("Welcome to the Fashion Outfit Generator!")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            break

        dataset_input = input("Dataset input: ")  # Get dataset-related input
        outfit_suggestion = generate_outfit_suggestion(user_input, dataset_input)
        print("GenAI:", outfit_suggestion)

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Fashion Outfit Generator!
# You: hii
# Dataset input: I want a fashion outfit
# GenAI: Sure! How about a navy blue blazer, a white top, blue jeans, and beige flats?
# You: can you suggest any shoes rather than flats
# Dataset input: can you suggest any shoes rather than flats
# GenAI: Sure, have you considered sneakers, boots, block heels, mules, or wedges?
# You: thank you
# Dataset input: i would prefer sneakers
# GenAI: Sure thing! What color would you like?
# You: thank you
# Dataset input: Black
# GenAI: You're welcome.
# You: black sneakers
# Dataset input: white sneakers
# GenAI: red sneakers
# You: ok fine
# Dataset input: but i want black or white sneakers
# GenAI: What's your budget?
# You: 1000
# Dataset input: 1000
# GenAI: 19
# You: oh
# Dataset input: below 1000
# GenAI: The dataset you are looking for must be smaller than 1000 items. Are you looking for a dataset with specific characteristics or features, such as in a particular field or industry?
# ...

# %%
#Static outfit Generator
import random

class OutfitGenerator:
    def __init__(self):
        self.styles = ["casual", "formal", "sporty"]
        self.colors = ["red", "blue", "green", "black", "white"]
        self.brands = ["Brand A", "Brand B", "Brand C"]

    def generate_outfit(self, user_preferences):
        style = user_preferences.get("style", random.choice(self.styles))
        colors = user_preferences.get("colors", random.choice(self.colors))
        brands = user_preferences.get("brands", random.choice(self.brands))

        # Generate outfit components based on user preferences
        outfit_components = {
            "top": f"{colors} {style} top from {random.choice(brands)}",
            "bottom": f"{colors} {style} pants from {random.choice(brands)}",
            "shoes": f"{colors} shoes from {random.choice(brands)}"
        }

        # Assemble outfit suggestion
        outfit_suggestion = f"You might like this outfit:\n" \
                            f"- {outfit_components['top']}\n" \
                            f"- {outfit_components['bottom']}\n" \
                            f"- {outfit_components['shoes']}"

        return outfit_suggestion

# Usage
if __name__ == "__main__":
    outfit_generator = OutfitGenerator()
    user_preferences = {
        "style": "casual",
        "colors": "blue",
        "brands": "Brand A, Brand B"
    }

    outfit_suggestion = outfit_generator.generate_outfit(user_preferences)
    print(outfit_suggestion)
# Out:
# You might like this outfit:
# - blue casual top from a
# - blue casual pants from d
# - blue shoes from

# %%
class ConversationalInterface:
    def __init__(self):
        self.user_preferences = {}

    def take_user_input(self, prompt):
        return input(prompt)

    def collect_user_preferences(self):
        print("Welcome to the Fashion Outfit Generator!")
        print("Please provide some information to personalize your outfits.")

        self.user_preferences["style"] = self.take_user_input("Preferred style (casual/formal/etc.): ")
        self.user_preferences["colors"] = self.take_user_input("Favorite colors (comma-separated): ")
        self.user_preferences["brands"] = self.take_user_input("Preferred brands (comma-separated): ")
        # You can collect more preferences as needed

    def collect_user_feedback(self):
        feedback = self.take_user_input("What do you like or dislike about the suggested outfit? ")

    def update_preferences_based_on_feedback(self):
        print("AI: Let's update your preferences based on your feedback.")
        feedback = self.take_user_input("AI: What aspect of the outfit would you like to change? ")

        # Example: Let's assume the user wants to change the color of the top
        new_color = self.take_user_input("AI: What color would you like for the top? ")
        self.user_preferences["colors"] = new_color

        print("AI: Thank you! I've updated your preferences.")

    def interact(self):
        self.collect_user_preferences()
        outfit_generator = OutfitGenerator()  # Your outfit generation logic here

        while True:
            # Generate and display an outfit suggestion
            outfit_suggestion = outfit_generator.generate_outfit(self.user_preferences)
            print("AI: Here's an outfit suggestion for you:")
            print(outfit_suggestion)

            # Collect user feedback
            self.collect_user_feedback()

            # Ask if the user wants to tweak the outfit
            tweak_outfit = self.take_user_input("AI: Do you want to tweak the outfit? (yes/no): ")
            if tweak_outfit.lower() != "yes":
                break

            # Update user preferences based on feedback
            self.update_preferences_based_on_feedback()

        print("Thank you for using the Fashion Outfit Generator!")

# Usage
if __name__ == "__main__":
    interface = ConversationalInterface()
    interface.interact()
# Out:
# Welcome to the Fashion Outfit Generator!
# Please provide some information to personalize your outfits.
# Preferred style (casual/formal/etc.): casual
# Favorite colors (comma-separated): Black,Green
# Preferred brands (comma-separated): Brand B
# AI: Here's an outfit suggestion for you:
# You might like this outfit:
# - Black,Green casual top from n
# - Black,Green casual pants from n
# - Black,Green shoes from n
# What do you like or dislike about the suggested outfit? Green shoes
# AI: Do you want to tweak the outfit? (yes/no): yes
# AI: Let's update your preferences based on your feedback.
# AI: What aspect of the outfit would you like to change? shoes
# AI: What color would you like for the top? white
# AI: Thank you! I've updated your preferences.
# AI: Here's an outfit suggestion for you:
# You might like this outfit:
# - white casual top from
# - white casual pants from B
# - white shoes from B
# What do you like or dislike about the suggested outfit? pants
# ...

# %%
#dynamic implementation of Outfit Generator
import random
import pandas as pd

class OutfitGenerator:
    def __init__(self, dataset_path):
        self.dataset = pd.read_csv("/content/sample_data/50rowsdata.csv", encoding='ISO-8859–1')

    def generate_outfit(self, user_preferences):
        matching_outfits = self.filter_outfits(user_preferences)
        if matching_outfits.empty:
            return "Sorry, no matching outfits found based on your preferences."

        chosen_outfit = random.choice(matching_outfits.index)
        outfit_components = matching_outfits.loc[chosen_outfit].to_dict()

        outfit_suggestion = f"Here's an outfit suggestion for you:\n"
        for key, value in outfit_components.items():
            outfit_suggestion += f"- {key}: {value}\n"

        return outfit_suggestion

    def filter_outfits(self, user_preferences):
        filters = {}
        for attribute in user_preferences:
            if attribute in self.dataset.columns:
                filters[attribute] = user_preferences[attribute]

        matching_outfits = self.dataset
        for attribute, value in filters.items():
            matching_outfits = matching_outfits[matching_outfits[attribute] == value]

        return matching_outfits

# Usage
if __name__ == "__main__":
    dataset_path = "/content/sample_data/50rowsdata.csv"  # Replace with the actual path to your dataset
    outfit_generator = OutfitGenerator(dataset_path)

    user_preferences = {}
    for column in outfit_generator.dataset.columns:
        user_input = input(f"Enter your preference for {column}: ")
        user_preferences[column] = user_input

    outfit_suggestion = outfit_generator.generate_outfit(user_preferences)
    print(outfit_suggestion)
# Out:
# Enter your preference for product_name: Casual Shirt
# Enter your preference for ProductBrand: Parx
# Enter your preference for Gender: Women
# Enter your preference for Price (INR): 799
# Enter your preference for NumImages: 5
# Enter your preference for color: Black
# Enter your preference for size: L
# Sorry, no matching outfits found based on your preferences.
